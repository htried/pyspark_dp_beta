# %%
# !pip install opendp-smartnoise
# Out:
# Collecting opendp-smartnoise
#   Using cached opendp_smartnoise-0.1.4.2-py3-none-any.whl (193 kB)
# Collecting antlr4-python3-runtime==4.8
#   Using cached antlr4-python3-runtime-4.8.tar.gz (112 kB)
# Requirement already satisfied: scipy in /srv/home/htriedman/.local/lib/python3.7/site-packages (from opendp-smartnoise) (1.5.4)
# Collecting pandasql
#   Using cached pandasql-0.7.3.tar.gz (26 kB)
# Collecting msrest
#   Using cached msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied: numpy in /srv/home/htriedman/.local/lib/python3.7/site-packages (from opendp-smartnoise) (1.19.5)
# Collecting statsmodels
#   Using cached statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied: pandas in /srv/home/htriedman/.local/lib/python3.7/site-packages (from opendp-smartnoise) (0.24.2)
# Requirement already satisfied: pyyaml in /usr/lib/anaconda-wmf/lib/python3.7/site-packages (from opendp-smartnoise) (5.4.1)
# Collecting opendp-smartnoise-core
#   Using cached opendp_smartnoise_core-0.2.2-py3-none-any.whl (12.7 MB)
# Collecting requests-oauthlib>=0.5.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from msrest->opendp-smartnoise) (2020.12.5)
# Requirement already satisfied: requests~=2.16 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from msrest->opendp-smartnoise) (2.25.1)
# Requirement already satisfied: six in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from isodate>=0.6.0->msrest->opendp-smartnoise) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from requests~=2.16->msrest->opendp-smartnoise) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from requests~=2.16->msrest->opendp-smartnoise) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/anaconda-wmf/lib/python3.7/site-packages (from requests~=2.16->msrest->opendp-smartnoise) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from requests-oauthlib>=0.5.0->msrest->opendp-smartnoise) (3.1.1)
# Requirement already satisfied: protobuf in /usr/lib/anaconda-wmf/lib/python3.7/site-packages (from opendp-smartnoise-core->opendp-smartnoise) (3.15.7)
# Requirement already satisfied: python-dateutil>=2.5.0 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from pandas->opendp-smartnoise) (2.8.1)
# Requirement already satisfied: pytz>=2011k in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from pandas->opendp-smartnoise) (2021.1)
# Requirement already satisfied: sqlalchemy in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from pandasql->opendp-smartnoise) (1.4.22)
# Requirement already satisfied: importlib-metadata in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from sqlalchemy->pandasql->opendp-smartnoise) (4.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from sqlalchemy->pandasql->opendp-smartnoise) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy->pandasql->opendp-smartnoise) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /srv/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy->pandasql->opendp-smartnoise) (3.4.1)
# Collecting patsy>=0.5
#   Using cached patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Building wheels for collected packages: antlr4-python3-runtime, pandasql
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=5dbfba82514f128933d646aa62d0414b21e11545d95657dcaafdbf75882456c3
#   Stored in directory: /srv/home/htriedman/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26818 sha256=ec51399a835e7cc179b5167179a5fbaab873737faf2fa9da7a8306079df177cb
#   Stored in directory: /srv/home/htriedman/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built antlr4-python3-runtime pandasql
# Installing collected packages: requests-oauthlib, patsy, isodate, statsmodels, pandasql, opendp-smartnoise-core, msrest, antlr4-python3-runtime, opendp-smartnoise
# Successfully installed antlr4-python3-runtime-4.8 isodate-0.6.0 msrest-0.6.21 opendp-smartnoise-0.1.4.2 opendp-smartnoise-core-0.2.2 pandasql-0.7.3 patsy-0.5.1 requests-oauthlib-1.3.0 statsmodels-0.12.2

# %%
import wmfdata
from dataclasses import dataclass
import numpy as np
import random
import math
from IPython.display import Latex
from opendp.smartnoise.core.api import LibraryWrapper

# %%
spark = wmfdata.spark.get_session(
    app_name='pyspark-large — differential privacy opendp test — htriedman',
    type='yarn-large',
    ship_python_env=True
)
# Out:
# Collecting packages...
# Packing environment at '/home/htriedman/.conda/envs/2021-08-31T19.46.22_htriedman' to 'conda-2021-08-31T19.46.22_htriedman.tgz'
# [########################################] | 100% Completed |  1min  6.2s
# Will ship conda-2021-08-31T19.46.22_htriedman.tgz to remote Spark executors.
# PySpark executors will use conda-2021-08-31T19.46.22_htriedman/bin/python3.

# %%
# get (page title, page id, project, country, actor signature) for Aug 15 2021 UTC6:00

rdd = spark.sql("""
SELECT
  pageview_info['page_title'] as page_title,
  page_id,
  pageview_info['project'] as project,
  geocoded_data['country'] as country,
  actor_signature
FROM wmf.pageview_actor
WHERE year = 2021 AND month = 8 AND day = 15 AND hour = 6 AND page_id IS NOT NULL
""").rdd

# %%
# add laplace noise to a single number
def add_laplace_noise(x, eps, sensitivity):
    return LibraryWrapper().laplace_mechanism(value=x, epsilon=eps, sensitivity=sensitivity, enforce_constant_time=False)

# add laplace noise to a spark rdd
def add_laplace_noise_to_rdd(rdd, eps, max_partitions, max_per_partition):
    eps_per_partition = eps / max_partitions
    sensitivity_per_partition = max_per_partition
    return rdd.map(lambda x: (x[0], add_laplace_noise(x[1], eps_per_partition, sensitivity_per_partition)))

# add gaussian noise to a single number
def add_gaussian_noise(x, eps, delta, sensitivity):
    return LibraryWrapper().gaussian_mechanism(value=x, epsilon=eps, delta=delta, sensitivity=sensitivity, enforce_constant_time=False)

# add laplace noise to a spark rdd
def add_gaussian_noise_to_rdd(rdd, eps, delta, max_partitions, max_per_partition):
    eps_per_partition = eps / max_partitions
    sensitivity_per_partition = max_per_partition
    return rdd.map(lambda x: (x[0], add_gaussian_noise(x[1], eps_per_partition, delta, sensitivity_per_partition)))

def calculate_threshold(eps, delta, max_partitions, max_per_partition):
    eps_per_partition = eps / max_partitions
    sensitivity_per_partition = max_per_partition
    b = sensitivity_per_partition / eps_per_partition
    return -b * math.log(2 * b * delta)

# %%
# do bounded DP count
def do_count(rdd, eps, delta, max_partitions, max_per_partition, noise_kind):
    # rekey to a tuple of (actor signature, page id)
    # ((actor_signature, page_id), pageview)
    dp_count_rdd = rdd.map(lambda x: ((x.actor_signature, x.page_id), [x]))

    # randomly get a set of at most `max_per_partition` pageviews for each (actor signature, page id) tuple
    # ((actor_signature, page_id), [pageview]) {max length of max_per_partition}
    dp_count_rdd = dp_count_rdd.reduceByKey(lambda x, y: random.sample(x + y, min(len(x) + len(y), max_per_partition)))

    # rekey to just actor signature
    # (actor_signature, [pageview]) {with redundancies}
    dp_count_rdd = dp_count_rdd.map(lambda x: ((x[0][0], x[1])))

    # randomly get a set of at most `max_partitions` sets of pageviews for each actor signature
    # (actor_signature, [pageview]) {max length of max_per_partition * max_partitions}
    dp_count_rdd = dp_count_rdd.reduceByKey(lambda x, y: random.sample(x + y, min(len(x) + len(y), max_partitions)))

    # drop actor signature as key
    # ([pageview])
    dp_count_rdd = dp_count_rdd.map(lambda x: x[1])

    # unnest lists of pageviews using a flatmap
    # (pageview)
    dp_count_rdd = dp_count_rdd.flatMap(lambda x: x)

    # now that contributions are bounded, count views per tuple
    dp_count_rdd = dp_count_rdd.map(lambda x: ((x.project, x.country, x.page_id, x.page_title), 1))
    dp_count_rdd = dp_count_rdd.reduceByKey(lambda x, y: (x + y))

    if noise_kind == "laplace":
        # add laplace noise to counts
        dp_count_rdd = add_laplace_noise_to_rdd(dp_count_rdd, eps, max_partitions, max_per_partition)
    elif noise_kind == "gaussian":
        dp_count_rdd = add_gaussian_noise_to_rdd(dp_count_rdd, eps, delta, max_partitions, max_per_partition)

    # filter tuples that have less than `min_number_of_views` views
    dp_count_rdd = dp_count_rdd.filter(lambda x: x[1] >= calculate_threshold(delta, eps, max_partitions, max_per_partition))

    # round view count to integers for readability
    dp_count_rdd = dp_count_rdd.map(lambda x: (x[0], round(x[1], 0)))

    return dp_count_rdd.takeOrdered(200, key=lambda x: -x[1])

# %%
# total contributions (aka sensitivity) = max_per_partition * max_partitions
max_partitions = 5    # say that users can visit at most 5 pages
max_per_partition = 2 # and for each page they can contribute at most 2 pageviews

eps = 1
delta = 5e-8

# %%
do_count(rdd, eps, delta, max_partitions, max_per_partition, "laplace")
# Out:
# [(('en.wikipedia', 'United States', 15580374, 'Main_Page'), 49278.0),
#  (('de.wikipedia', 'Germany', 5248757, 'Wikipedia:Hauptseite'), 24422.0),
#  (('ja.wikipedia', 'Japan', 253348, 'メインページ'), 24252.0),
#  (('en.wikipedia', 'India', 15580374, 'Main_Page'), 16174.0),
#  (('en.wikipedia', 'United Kingdom', 15580374, 'Main_Page'), 13111.0),
#  (('fr.wikipedia', 'Russia', 1034876, 'Questionnaire'), 11548.0),
#  (('ja.wikipedia', 'Japan', 3093109, 'ジャッキー・ウー'), 11447.0),
#  (('fr.wikipedia', 'France', 10635368, 'Wikipédia:Accueil_principal'),
#   10302.0),
#  (('en.wikipedia', 'India', 3349824, 'Vikram_Batra'), 9975.0),
#  (('ja.wikipedia', 'Japan', 2069252, '鍛治舎巧'), 9652.0),
#  (('it.wikipedia', 'Italy', 665216, "Gianfranco_D'Angelo"), 9565.0),
#  (('ja.wikipedia', 'Japan', 303551, '馬淵史郎'), 8340.0),
#  (('en.wikipedia', 'India', 2499568, 'Independence_Day_(India)'), 8194.0),
#  (('en.wikipedia', 'Australia', 15580374, 'Main_Page'), 7942.0),
#  (('en.wikipedia', 'Iran', 15580374, 'Main_Page'), 7925.0),
#  (('ja.wikipedia', 'Japan', 1535394, '万朶隊'), 7524.0),
#  (('en.wikipedia', 'Brazil', 44486544, '2015_in_British_television'), 7478.0),
#  (('it.wikipedia', 'Italy', 445746, 'Ferragosto'), 7449.0),
#  (('en.wikipedia', 'Brazil', 52925867, '2018_in_American_television'), 7397.0),
#  (('en.wikipedia',
#    'Brazil',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   7392.0),
#  (('en.wikipedia',
#    'Brazil',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   7365.0),
#  (('en.wikipedia',
#    'Brazil',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   7353.0),
#  (('en.wikipedia', 'Brazil', 4848272, 'Donald_Trump'), 7343.0),
#  (('en.wikipedia',
#    'Brazil',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   7340.0),
#  (('en.wikipedia', 'Brazil', 48969854, '2017_in_American_television'), 7332.0),
#  (('en.wikipedia', 'Brazil', 48980006, '2016_in_aviation'), 7307.0),
#  (('en.wikipedia',
#    'Brazil',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   7291.0),
#  (('en.wikipedia',
#    'Brazil',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   7280.0),
#  (('en.wikipedia',
#    'Brazil',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   7256.0),
#  (('en.wikipedia',
#    'Brazil',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   7238.0),
#  (('en.wikipedia', 'Brazil', 50034356, 'Panama_Papers'), 7200.0),
#  (('en.wikipedia',
#    'Brazil',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   7191.0),
#  (('en.wikipedia', 'Brazil', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   7163.0),
#  (('en.wikipedia', 'Brazil', 236034, 'List_of_municipalities_in_Michigan'),
#   7149.0),
#  (('en.wikipedia', 'Brazil', 55547578, '2018_in_arthropod_paleontology'),
#   7147.0),
#  (('en.wikipedia',
#    'Philippines',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   6614.0),
#  (('en.wikipedia',
#    'Philippines',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   6592.0),
#  (('en.wikipedia',
#    'Philippines',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   6577.0),
#  (('en.wikipedia',
#    'Philippines',
#    236034,
#    'List_of_municipalities_in_Michigan'),
#   6563.0),
#  (('en.wikipedia', 'Philippines', 4848272, 'Donald_Trump'), 6544.0),
#  (('en.wikipedia',
#    'Philippines',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   6541.0),
#  (('en.wikipedia', 'Philippines', 48969854, '2017_in_American_television'),
#   6540.0),
#  (('en.wikipedia', 'Philippines', 55547578, '2018_in_arthropod_paleontology'),
#   6489.0),
#  (('en.wikipedia',
#    'Philippines',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   6487.0),
#  (('en.wikipedia',
#    'Philippines',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   6470.0),
#  (('en.wikipedia', 'Philippines', 50034356, 'Panama_Papers'), 6467.0),
#  (('en.wikipedia', 'Philippines', 44486544, '2015_in_British_television'),
#   6457.0),
#  (('en.wikipedia',
#    'Philippines',
#    9087364,
#    'Islamic_State_of_Iraq_and_the_Levant'),
#   6454.0),
#  (('en.wikipedia',
#    'Philippines',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   6444.0),
#  (('en.wikipedia', 'Philippines', 52925867, '2018_in_American_television'),
#   6441.0),
#  (('en.wikipedia', 'Philippines', 48980006, '2016_in_aviation'), 6410.0),
#  (('en.wikipedia',
#    'Philippines',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   6402.0),
#  (('en.wikipedia',
#    'Philippines',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   6348.0),
#  (('ru.wikipedia', 'Russia', 4401, 'Заглавная_страница'), 6104.0),
#  (('it.wikipedia', 'Italy', 521472, 'Pagina_principale'), 6029.0),
#  (('ja.wikipedia', 'Japan', 509898, '富永恭次'), 5870.0),
#  (('en.wikipedia', 'India', 4102537, 'Nayanthara'), 4814.0),
#  (('ja.wikipedia', 'Japan', 2779254, '吉村由美'), 4727.0),
#  (('zh.wikipedia', 'Taiwan', 6836331, '斯卡羅_(電視劇)'), 4547.0),
#  (('ja.wikipedia', 'Japan', 2779257, '大貫亜美'), 4529.0),
#  (('zh.wikipedia', 'United States', 3597889, 'Wikipedia:首页'), 4503.0),
#  (('en.wikipedia', 'Canada', 15580374, 'Main_Page'), 4480.0),
#  (('ja.wikipedia', 'Japan', 2593279, 'DaiGo'), 4196.0),
#  (('it.wikipedia', 'Italy', 1603963, 'Assunzione_di_Maria'), 4006.0),
#  (('en.wikipedia', 'India', 60318741, 'Bhuj:_The_Pride_of_India'), 3969.0),
#  (('ja.wikipedia', 'Japan', 22741, '終戦の日'), 3752.0),
#  (('es.wikipedia', 'United States', 2271189, 'Wikipedia:Portada'), 3746.0),
#  (('en.wikipedia', 'India', 60600284, 'Shershaah'), 3710.0),
#  (('ja.wikipedia', 'Japan', 540351, '明徳義塾中学校・高等学校'), 3651.0),
#  (('ru.wikipedia', 'United States', 4401, 'Заглавная_страница'), 3494.0),
#  (('sv.wikipedia', 'Sweden', 902605, 'Portal:Huvudsida'), 3490.0),
#  (('ja.wikipedia', 'Japan', 1661411, '第4飛行師団_(日本軍)'), 3487.0),
#  (('en.wikipedia', 'South Africa', 15580374, 'Main_Page'), 3440.0),
#  (('fr.wikipedia', 'United States', 10635368, 'Wikipédia:Accueil_principal'),
#   3382.0),
#  (('de.wikipedia', 'Germany', 5070, 'Taliban'), 3378.0),
#  (('ja.wikipedia', 'United States', 253348, 'メインページ'), 3362.0),
#  (('en.wikipedia', 'India', 978203, 'Flag_of_India'), 3300.0),
#  (('en.wikipedia', 'United States', 41109403, 'Attacks_on_parachutists'),
#   3269.0),
#  (('de.wikipedia', 'United States', 5248757, 'Wikipedia:Hauptseite'), 3259.0),
#  (('it.wikipedia', 'United States', 521472, 'Pagina_principale'), 3212.0),
#  (('en.wikipedia', 'Germany', 15580374, 'Main_Page'), 3197.0),
#  (('pt.wikipedia', 'United States', 952, 'Wikipédia:Página_principal'),
#   3163.0),
#  (('en.wikipedia', 'United States', 49632909, 'The_Suicide_Squad_(film)'),
#   3104.0),
#  (('en.wikipedia', 'India', 60827, 'Cleopatra'), 3068.0),
#  (('it.wikipedia', 'Italy', 129532, 'Piera_Degli_Esposti'), 3054.0),
#  (('en.wikipedia', 'United Arab Emirates', 15580374, 'Main_Page'), 2992.0),
#  (('ja.wikipedia', 'Japan', 6657, 'PUFFY'), 2968.0),
#  (('fa.wikipedia', 'Iran', 27859, 'طالبان'), 2939.0),
#  (('en.wikipedia',
#    'India',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   2877.0),
#  (('fr.wikipedia', 'France', 37581, 'Assomption_de_Marie'), 2870.0),
#  (('nl.wikipedia', 'Netherlands', 722, 'Hoofdpagina'), 2868.0),
#  (('en.wikipedia',
#    'India',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   2865.0),
#  (('en.wikipedia',
#    'India',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   2853.0),
#  (('en.wikipedia', 'India', 52925867, '2018_in_American_television'), 2851.0),
#  (('en.wikipedia', 'India', 55547578, '2018_in_arthropod_paleontology'),
#   2844.0),
#  (('en.wikipedia', 'India', 4848272, 'Donald_Trump'), 2837.0),
#  (('en.wikipedia',
#    'India',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   2826.0),
#  (('en.wikipedia', 'India', 50034356, 'Panama_Papers'), 2826.0),
#  (('en.wikipedia', 'India', 44486544, '2015_in_British_television'), 2824.0),
#  (('en.wikipedia', 'India', 56207055, 'List_of_2010s_deaths_in_rock_and_roll'),
#   2821.0),
#  (('en.wikipedia',
#    'India',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   2818.0),
#  (('en.wikipedia', 'India', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   2811.0),
#  (('en.wikipedia', 'India', 55175661, 'List_of_2018–19_Super_Rugby_transfers'),
#   2808.0),
#  (('en.wikipedia', 'India', 30635, 'Taliban'), 2801.0),
#  (('en.wikipedia', 'India', 236034, 'List_of_municipalities_in_Michigan'),
#   2796.0),
#  (('en.wikipedia',
#    'India',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   2781.0),
#  (('en.wikipedia', 'India', 48980006, '2016_in_aviation'), 2777.0),
#  (('es.wikipedia', 'Mexico', 2271189, 'Wikipedia:Portada'), 2762.0),
#  (('en.wikipedia', 'India', 48969854, '2017_in_American_television'), 2755.0),
#  (('en.wikipedia',
#    'India',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   2752.0),
#  (('ja.wikipedia', 'Japan', 4279901, 'コージ・トクダ'), 2681.0),
#  (('en.wikipedia', 'India', 56280, 'Jana_Gana_Mana'), 2599.0),
#  (('fr.wikipedia', 'France', 391767, 'Annette_Messager'), 2581.0),
#  (('en.wikipedia', 'Pakistan', 15580374, 'Main_Page'), 2528.0),
#  (('ja.wikipedia', 'Japan', 460326, '岐阜県立岐阜商業高等学校'), 2512.0),
#  (('de.wikipedia', 'Switzerland', 5248757, 'Wikipedia:Hauptseite'), 2405.0),
#  (('de.wikipedia', 'Austria', 5248757, 'Wikipedia:Hauptseite'), 2399.0),
#  (('ja.wikipedia', 'Japan', 2826002, '唐橋ユミ'), 2378.0),
#  (('it.wikipedia', 'Italy', 6125958, 'Tammy_Abraham'), 2358.0),
#  (('es.wikipedia', 'Spain', 2271189, 'Wikipedia:Portada'), 2351.0),
#  (('en.wikipedia', 'United States', 30635, 'Taliban'), 2333.0),
#  (('pl.wikipedia', 'Poland', 2956678, 'Wikipedia:Strona_główna'), 2325.0),
#  (('en.wikipedia', 'Philippines', 15580374, 'Main_Page'), 2321.0),
#  (('ja.wikipedia', 'Japan', 1145395, 'ジェリー藤尾'), 2315.0),
#  (('en.wikipedia', 'United Kingdom', 30635, 'Taliban'), 2235.0),
#  (('en.wikipedia', 'Singapore', 15580374, 'Main_Page'), 2159.0),
#  (('zh.wikipedia', 'Taiwan', 3597889, 'Wikipedia:首页'), 2118.0),
#  (('ja.wikipedia', 'Japan', 3232590, 'ヘンダーソン_(お笑い)'), 2099.0),
#  (('ja.wikipedia', 'Japan', 238129, '今井ゆうぞう'), 2054.0),
#  (('en.wikipedia',
#    'Mexico',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   2051.0),
#  (('en.wikipedia',
#    'Mexico',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   2037.0),
#  (('en.wikipedia', 'Mexico', 236034, 'List_of_municipalities_in_Michigan'),
#   2034.0),
#  (('en.wikipedia',
#    'Mexico',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   2027.0),
#  (('en.wikipedia', 'Mexico', 50034356, 'Panama_Papers'), 2017.0),
#  (('en.wikipedia',
#    'Argentina',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   1999.0),
#  (('en.wikipedia',
#    'Mexico',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   1990.0),
#  (('en.wikipedia',
#    'Mexico',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   1987.0),
#  (('en.wikipedia', 'Mexico', 55547578, '2018_in_arthropod_paleontology'),
#   1981.0),
#  (('en.wikipedia', 'Mexico', 48980006, '2016_in_aviation'), 1978.0),
#  (('en.wikipedia',
#    'Argentina',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   1972.0),
#  (('en.wikipedia', 'Mexico', 52925867, '2018_in_American_television'), 1968.0),
#  (('en.wikipedia',
#    'Mexico',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   1968.0),
#  (('en.wikipedia', 'Mexico', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   1966.0),
#  (('ru.wikipedia', 'Russia', 71896, 'Талибан'), 1960.0),
#  (('en.wikipedia', 'Mexico', 44486544, '2015_in_British_television'), 1960.0),
#  (('zh.wikipedia', 'Taiwan', 7301738, '俗女養成記2'), 1959.0),
#  (('en.wikipedia',
#    'Argentina',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   1956.0),
#  (('en.wikipedia',
#    'Mexico',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   1951.0),
#  (('en.wikipedia', 'Argentina', 55547578, '2018_in_arthropod_paleontology'),
#   1951.0),
#  (('en.wikipedia', 'Mexico', 48969854, '2017_in_American_television'), 1949.0),
#  (('en.wikipedia', 'Mexico', 4848272, 'Donald_Trump'), 1941.0),
#  (('en.wikipedia', 'Argentina', 52925867, '2018_in_American_television'),
#   1933.0),
#  (('en.wikipedia', 'Argentina', 44486544, '2015_in_British_television'),
#   1932.0),
#  (('en.wikipedia', 'Argentina', 50034356, 'Panama_Papers'), 1932.0),
#  (('en.wikipedia',
#    'Argentina',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   1927.0),
#  (('en.wikipedia',
#    'Argentina',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   1926.0),
#  (('ja.wikipedia', 'Japan', 3571127, '東京卍リベンジャーズ'), 1922.0),
#  (('en.wikipedia',
#    'Mexico',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   1918.0),
#  (('en.wikipedia',
#    'Argentina',
#    9087364,
#    'Islamic_State_of_Iraq_and_the_Levant'),
#   1918.0),
#  (('en.wikipedia',
#    'Argentina',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   1913.0),
#  (('en.wikipedia', 'Argentina', 236034, 'List_of_municipalities_in_Michigan'),
#   1900.0),
#  (('en.wikipedia', 'Argentina', 48980006, '2016_in_aviation'), 1898.0),
#  (('ml.wikipedia', 'India', 42375, 'ഒന്നാം_ഇന്ത്യൻ_സ്വാതന്ത്ര്യ_സമരം_(1857)'),
#   1894.0),
#  (('it.wikipedia', 'Italy', 1340312, 'Gino_Strada'), 1893.0),
#  (('en.wikipedia',
#    'Argentina',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   1891.0),
#  (('en.wikipedia', 'Argentina', 48969854, '2017_in_American_television'),
#   1890.0),
#  (('en.wikipedia',
#    'Mexico',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   1883.0),
#  (('en.wikipedia', 'Argentina', 4848272, 'Donald_Trump'), 1882.0),
#  (('ja.wikipedia', 'Japan', 1613, '日本のいちばん長い日'), 1880.0),
#  (('en.wikipedia',
#    'Argentina',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   1875.0),
#  (('en.wikipedia',
#    'Argentina',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   1872.0),
#  (('en.wikipedia', 'India', 68273579, 'Bheemla_Nayak'), 1869.0),
#  (('fr.wikipedia', 'France', 8674, 'Haïti'), 1861.0),
#  (('zh.wikipedia', 'Hong Kong', 594262, '破壞之王'), 1842.0),
#  (('en.wikipedia', 'United Kingdom', 57379245, 'Incel'), 1825.0),
#  (('ko.wikipedia', 'South Korea', 1579615, '더블랙레이블'), 1812.0),
#  (('zh.wikipedia', 'Taiwan', 23730, '海地'), 1810.0),
#  (('en.wikipedia', 'India', 1425939, 'Indian_Idol'), 1774.0),
#  (('zh.wikipedia', 'Hong Kong', 3597889, 'Wikipedia:首页'), 1749.0),
#  (('en.wikipedia', 'Sweden', 15580374, 'Main_Page'), 1749.0),
#  (('ja.wikipedia', 'Japan', 5451, 'もののけ姫'), 1734.0),
#  (('it.wikipedia', 'Italy', 65507, 'Talebani'), 1730.0),
#  (('ja.wikipedia', 'Japan', 456928, 'ノースアジア大学明桜高等学校'), 1727.0),
#  (('de.wikipedia', 'Germany', 154, 'Afghanistan'), 1724.0),
#  (('en.wikipedia', 'Malaysia', 15580374, 'Main_Page'), 1700.0),
#  (('ru.wikipedia', 'Russia', 80217, 'Новикова,_Клара_Борисовна'), 1680.0),
#  (('it.wikipedia', 'Italy', 3363477, "Daniela_D'Angelo"), 1675.0),
#  (('en.wikipedia', 'United States', 60203476, 'Free_Guy'), 1665.0),
#  (('en.wikipedia', 'United States', 20646122, 'Index.html'), 1652.0),
#  (('ja.wikipedia', 'Japan', 81004, '河野景子'), 1645.0),
#  (('ja.wikipedia', 'Japan', 43815, '梅田えりか'), 1621.0),
#  (('ja.wikipedia', 'Japan', 3245938, '柴田阿弥'), 1601.0),
#  (('en.wikipedia', 'India', 14533, 'India'), 1576.0),
#  (('ko.wikipedia', 'South Korea', 27949, '광복절'), 1573.0),
#  (('en.wikipedia', 'India', 2488796, 'Republic_Day_(India)'), 1568.0),
#  (('en.wikipedia', 'India', 803754, 'Kargil_War'), 1561.0),
#  (('ja.wikipedia', 'Japan', 780840, '松井秀喜5打席連続敬遠'), 1558.0),
#  (('fi.wikipedia', 'Finland', 291, 'Wikipedia:Etusivu'), 1543.0),
#  (('en.wikipedia', 'United States', 60577671, 'Beckett_(film)'), 1520.0),
#  (('ja.wikipedia', 'Japan', 62134, 'A級戦犯'), 1519.0)]

# %%
do_count(rdd, eps, delta, max_partitions, max_per_partition, "gaussian")
# Out:
# [(('en.wikipedia', 'United States', 15580374, 'Main_Page'), 49256.0),
#  (('de.wikipedia', 'Germany', 5248757, 'Wikipedia:Hauptseite'), 24451.0),
#  (('ja.wikipedia', 'Japan', 253348, 'メインページ'), 24302.0),
#  (('en.wikipedia', 'India', 15580374, 'Main_Page'), 16133.0),
#  (('en.wikipedia', 'United Kingdom', 15580374, 'Main_Page'), 13123.0),
#  (('fr.wikipedia', 'Russia', 1034876, 'Questionnaire'), 11564.0),
#  (('ja.wikipedia', 'Japan', 3093109, 'ジャッキー・ウー'), 11472.0),
#  (('fr.wikipedia', 'France', 10635368, 'Wikipédia:Accueil_principal'),
#   10360.0),
#  (('en.wikipedia', 'India', 3349824, 'Vikram_Batra'), 10026.0),
#  (('ja.wikipedia', 'Japan', 2069252, '鍛治舎巧'), 9673.0),
#  (('it.wikipedia', 'Italy', 665216, "Gianfranco_D'Angelo"), 9572.0),
#  (('ja.wikipedia', 'Japan', 303551, '馬淵史郎'), 8375.0),
#  (('en.wikipedia', 'India', 2499568, 'Independence_Day_(India)'), 8207.0),
#  (('en.wikipedia', 'Iran', 15580374, 'Main_Page'), 7948.0),
#  (('en.wikipedia', 'Australia', 15580374, 'Main_Page'), 7926.0),
#  (('en.wikipedia', 'Brazil', 44486544, '2015_in_British_television'), 7554.0),
#  (('ja.wikipedia', 'Japan', 1535394, '万朶隊'), 7514.0),
#  (('it.wikipedia', 'Italy', 445746, 'Ferragosto'), 7466.0),
#  (('en.wikipedia',
#    'Brazil',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   7464.0),
#  (('en.wikipedia',
#    'Brazil',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   7398.0),
#  (('en.wikipedia', 'Brazil', 48969854, '2017_in_American_television'), 7392.0),
#  (('en.wikipedia',
#    'Brazil',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   7379.0),
#  (('en.wikipedia',
#    'Brazil',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   7345.0),
#  (('en.wikipedia', 'Brazil', 48980006, '2016_in_aviation'), 7307.0),
#  (('en.wikipedia',
#    'Brazil',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   7304.0),
#  (('en.wikipedia', 'Brazil', 52925867, '2018_in_American_television'), 7275.0),
#  (('en.wikipedia', 'Brazil', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   7267.0),
#  (('en.wikipedia',
#    'Brazil',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   7248.0),
#  (('en.wikipedia', 'Brazil', 4848272, 'Donald_Trump'), 7248.0),
#  (('en.wikipedia',
#    'Brazil',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   7237.0),
#  (('en.wikipedia', 'Brazil', 236034, 'List_of_municipalities_in_Michigan'),
#   7215.0),
#  (('en.wikipedia', 'Brazil', 55547578, '2018_in_arthropod_paleontology'),
#   7211.0),
#  (('en.wikipedia', 'Brazil', 50034356, 'Panama_Papers'), 7174.0),
#  (('en.wikipedia',
#    'Brazil',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   7169.0),
#  (('en.wikipedia',
#    'Brazil',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   7165.0),
#  (('en.wikipedia',
#    'Philippines',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   6642.0),
#  (('en.wikipedia',
#    'Philippines',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   6620.0),
#  (('en.wikipedia',
#    'Philippines',
#    236034,
#    'List_of_municipalities_in_Michigan'),
#   6619.0),
#  (('en.wikipedia', 'Philippines', 4848272, 'Donald_Trump'), 6575.0),
#  (('en.wikipedia',
#    'Philippines',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   6567.0),
#  (('en.wikipedia',
#    'Philippines',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   6520.0),
#  (('en.wikipedia',
#    'Philippines',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   6516.0),
#  (('en.wikipedia', 'Philippines', 48969854, '2017_in_American_television'),
#   6501.0),
#  (('en.wikipedia', 'Philippines', 55547578, '2018_in_arthropod_paleontology'),
#   6481.0),
#  (('en.wikipedia',
#    'Philippines',
#    9087364,
#    'Islamic_State_of_Iraq_and_the_Levant'),
#   6471.0),
#  (('en.wikipedia', 'Philippines', 50034356, 'Panama_Papers'), 6449.0),
#  (('en.wikipedia',
#    'Philippines',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   6448.0),
#  (('en.wikipedia', 'Philippines', 48980006, '2016_in_aviation'), 6438.0),
#  (('en.wikipedia',
#    'Philippines',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   6425.0),
#  (('en.wikipedia', 'Philippines', 52925867, '2018_in_American_television'),
#   6406.0),
#  (('en.wikipedia', 'Philippines', 44486544, '2015_in_British_television'),
#   6396.0),
#  (('en.wikipedia',
#    'Philippines',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   6324.0),
#  (('en.wikipedia',
#    'Philippines',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   6310.0),
#  (('ru.wikipedia', 'Russia', 4401, 'Заглавная_страница'), 6064.0),
#  (('it.wikipedia', 'Italy', 521472, 'Pagina_principale'), 6059.0),
#  (('ja.wikipedia', 'Japan', 509898, '富永恭次'), 5862.0),
#  (('ja.wikipedia', 'Japan', 2779254, '吉村由美'), 4838.0),
#  (('en.wikipedia', 'India', 4102537, 'Nayanthara'), 4780.0),
#  (('zh.wikipedia', 'Taiwan', 6836331, '斯卡羅_(電視劇)'), 4554.0),
#  (('ja.wikipedia', 'Japan', 2779257, '大貫亜美'), 4520.0),
#  (('en.wikipedia', 'Canada', 15580374, 'Main_Page'), 4499.0),
#  (('zh.wikipedia', 'United States', 3597889, 'Wikipedia:首页'), 4469.0),
#  (('ja.wikipedia', 'Japan', 2593279, 'DaiGo'), 4272.0),
#  (('it.wikipedia', 'Italy', 1603963, 'Assunzione_di_Maria'), 3995.0),
#  (('en.wikipedia', 'India', 60318741, 'Bhuj:_The_Pride_of_India'), 3942.0),
#  (('es.wikipedia', 'United States', 2271189, 'Wikipedia:Portada'), 3803.0),
#  (('ja.wikipedia', 'Japan', 22741, '終戦の日'), 3711.0),
#  (('ja.wikipedia', 'Japan', 540351, '明徳義塾中学校・高等学校'), 3635.0),
#  (('en.wikipedia', 'India', 60600284, 'Shershaah'), 3571.0),
#  (('ru.wikipedia', 'United States', 4401, 'Заглавная_страница'), 3564.0),
#  (('sv.wikipedia', 'Sweden', 902605, 'Portal:Huvudsida'), 3509.0),
#  (('en.wikipedia', 'South Africa', 15580374, 'Main_Page'), 3483.0),
#  (('ja.wikipedia', 'Japan', 1661411, '第4飛行師団_(日本軍)'), 3455.0),
#  (('de.wikipedia', 'United States', 5248757, 'Wikipedia:Hauptseite'), 3357.0),
#  (('ja.wikipedia', 'United States', 253348, 'メインページ'), 3354.0),
#  (('fr.wikipedia', 'United States', 10635368, 'Wikipédia:Accueil_principal'),
#   3353.0),
#  (('en.wikipedia', 'India', 978203, 'Flag_of_India'), 3338.0),
#  (('de.wikipedia', 'Germany', 5070, 'Taliban'), 3301.0),
#  (('en.wikipedia', 'United States', 41109403, 'Attacks_on_parachutists'),
#   3213.0),
#  (('en.wikipedia', 'Germany', 15580374, 'Main_Page'), 3170.0),
#  (('it.wikipedia', 'United States', 521472, 'Pagina_principale'), 3165.0),
#  (('pt.wikipedia', 'United States', 952, 'Wikipédia:Página_principal'),
#   3163.0),
#  (('en.wikipedia', 'India', 60827, 'Cleopatra'), 3146.0),
#  (('it.wikipedia', 'Italy', 129532, 'Piera_Degli_Esposti'), 3117.0),
#  (('en.wikipedia', 'United States', 49632909, 'The_Suicide_Squad_(film)'),
#   3070.0),
#  (('en.wikipedia', 'United Arab Emirates', 15580374, 'Main_Page'), 3008.0),
#  (('fa.wikipedia', 'Iran', 27859, 'طالبان'), 2939.0),
#  (('en.wikipedia', 'India', 55547578, '2018_in_arthropod_paleontology'),
#   2909.0),
#  (('en.wikipedia', 'India', 44486544, '2015_in_British_television'), 2905.0),
#  (('fr.wikipedia', 'France', 37581, 'Assomption_de_Marie'), 2885.0),
#  (('en.wikipedia',
#    'India',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   2873.0),
#  (('en.wikipedia', 'India', 52925867, '2018_in_American_television'), 2848.0),
#  (('en.wikipedia',
#    'India',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   2834.0),
#  (('en.wikipedia', 'India', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   2831.0),
#  (('ja.wikipedia', 'Japan', 6657, 'PUFFY'), 2829.0),
#  (('en.wikipedia',
#    'India',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   2820.0),
#  (('en.wikipedia', 'India', 50034356, 'Panama_Papers'), 2809.0),
#  (('en.wikipedia',
#    'India',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   2807.0),
#  (('en.wikipedia', 'India', 55175661, 'List_of_2018–19_Super_Rugby_transfers'),
#   2797.0),
#  (('nl.wikipedia', 'Netherlands', 722, 'Hoofdpagina'), 2790.0),
#  (('en.wikipedia', 'India', 56207055, 'List_of_2010s_deaths_in_rock_and_roll'),
#   2776.0),
#  (('en.wikipedia', 'India', 4848272, 'Donald_Trump'), 2775.0),
#  (('en.wikipedia', 'India', 30635, 'Taliban'), 2772.0),
#  (('en.wikipedia',
#    'India',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   2755.0),
#  (('en.wikipedia',
#    'India',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   2750.0),
#  (('en.wikipedia', 'India', 236034, 'List_of_municipalities_in_Michigan'),
#   2748.0),
#  (('en.wikipedia', 'India', 48969854, '2017_in_American_television'), 2746.0),
#  (('en.wikipedia',
#    'India',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   2744.0),
#  (('fr.wikipedia', 'France', 391767, 'Annette_Messager'), 2728.0),
#  (('en.wikipedia', 'India', 48980006, '2016_in_aviation'), 2705.0),
#  (('ja.wikipedia', 'Japan', 4279901, 'コージ・トクダ'), 2703.0),
#  (('es.wikipedia', 'Mexico', 2271189, 'Wikipedia:Portada'), 2694.0),
#  (('en.wikipedia', 'India', 56280, 'Jana_Gana_Mana'), 2593.0),
#  (('ja.wikipedia', 'Japan', 460326, '岐阜県立岐阜商業高等学校'), 2575.0),
#  (('en.wikipedia', 'Pakistan', 15580374, 'Main_Page'), 2523.0),
#  (('de.wikipedia', 'Switzerland', 5248757, 'Wikipedia:Hauptseite'), 2476.0),
#  (('es.wikipedia', 'Spain', 2271189, 'Wikipedia:Portada'), 2455.0),
#  (('ja.wikipedia', 'Japan', 2826002, '唐橋ユミ'), 2451.0),
#  (('it.wikipedia', 'Italy', 6125958, 'Tammy_Abraham'), 2445.0),
#  (('de.wikipedia', 'Austria', 5248757, 'Wikipedia:Hauptseite'), 2353.0),
#  (('ja.wikipedia', 'Japan', 1145395, 'ジェリー藤尾'), 2340.0),
#  (('pl.wikipedia', 'Poland', 2956678, 'Wikipedia:Strona_główna'), 2340.0),
#  (('en.wikipedia', 'United States', 30635, 'Taliban'), 2330.0),
#  (('en.wikipedia', 'Philippines', 15580374, 'Main_Page'), 2292.0),
#  (('ja.wikipedia', 'Japan', 3232590, 'ヘンダーソン_(お笑い)'), 2193.0),
#  (('en.wikipedia', 'United Kingdom', 30635, 'Taliban'), 2172.0),
#  (('en.wikipedia', 'Singapore', 15580374, 'Main_Page'), 2121.0),
#  (('en.wikipedia',
#    'Mexico',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   2080.0),
#  (('en.wikipedia', 'Mexico', 48980006, '2016_in_aviation'), 2075.0),
#  (('en.wikipedia',
#    'Mexico',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   2065.0),
#  (('en.wikipedia', 'Mexico', 52925867, '2018_in_American_television'), 2054.0),
#  (('zh.wikipedia', 'Taiwan', 3597889, 'Wikipedia:首页'), 2051.0),
#  (('en.wikipedia', 'Argentina', 55547578, '2018_in_arthropod_paleontology'),
#   2047.0),
#  (('en.wikipedia', 'Mexico', 4848272, 'Donald_Trump'), 2034.0),
#  (('en.wikipedia', 'Argentina', 50034356, 'Panama_Papers'), 2031.0),
#  (('en.wikipedia',
#    'Argentina',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   2006.0),
#  (('zh.wikipedia', 'Taiwan', 7301738, '俗女養成記2'), 1995.0),
#  (('en.wikipedia', 'Mexico', 50034356, 'Panama_Papers'), 1992.0),
#  (('ja.wikipedia', 'Japan', 238129, '今井ゆうぞう'), 1989.0),
#  (('en.wikipedia',
#    'Mexico',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   1985.0),
#  (('en.wikipedia',
#    'Argentina',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   1984.0),
#  (('en.wikipedia',
#    'Argentina',
#    56207055,
#    'List_of_2010s_deaths_in_rock_and_roll'),
#   1984.0),
#  (('en.wikipedia', 'Mexico', 44486544, '2015_in_British_television'), 1984.0),
#  (('en.wikipedia', 'Mexico', 236034, 'List_of_municipalities_in_Michigan'),
#   1976.0),
#  (('en.wikipedia', 'Argentina', 44486544, '2015_in_British_television'),
#   1973.0),
#  (('en.wikipedia', 'Mexico', 9087364, 'Islamic_State_of_Iraq_and_the_Levant'),
#   1972.0),
#  (('ja.wikipedia', 'Japan', 3571127, '東京卍リベンジャーズ'), 1968.0),
#  (('en.wikipedia', 'Mexico', 55547578, '2018_in_arthropod_paleontology'),
#   1966.0),
#  (('en.wikipedia',
#    'Mexico',
#    4644339,
#    'List_of_United_States_Representatives_from_New_York'),
#   1966.0),
#  (('en.wikipedia',
#    'Mexico',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   1963.0),
#  (('en.wikipedia',
#    'Mexico',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   1952.0),
#  (('en.wikipedia',
#    'Argentina',
#    38892181,
#    'List_of_United_States_counties_and_county_equivalents'),
#   1945.0),
#  (('en.wikipedia', 'Argentina', 48969854, '2017_in_American_television'),
#   1942.0),
#  (('en.wikipedia', 'Mexico', 48969854, '2017_in_American_television'), 1935.0),
#  (('en.wikipedia',
#    'Argentina',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   1923.0),
#  (('it.wikipedia', 'Italy', 1340312, 'Gino_Strada'), 1922.0),
#  (('en.wikipedia',
#    'Argentina',
#    46230181,
#    'Saudi_Arabian-led_intervention_in_Yemen'),
#   1919.0),
#  (('ru.wikipedia', 'Russia', 71896, 'Талибан'), 1914.0),
#  (('en.wikipedia',
#    'Mexico',
#    54266373,
#    'Special_Counsel_investigation_(2017–2019)'),
#   1896.0),
#  (('en.wikipedia',
#    'Argentina',
#    55175661,
#    'List_of_2018–19_Super_Rugby_transfers'),
#   1895.0),
#  (('en.wikipedia', 'Argentina', 236034, 'List_of_municipalities_in_Michigan'),
#   1890.0),
#  (('en.wikipedia',
#    'Argentina',
#    9087364,
#    'Islamic_State_of_Iraq_and_the_Levant'),
#   1888.0),
#  (('en.wikipedia',
#    'Argentina',
#    54115568,
#    'Timeline_of_Russian_interference_in_the_2016_United_States_elections'),
#   1886.0),
#  (('fr.wikipedia', 'France', 8674, 'Haïti'), 1866.0),
#  (('en.wikipedia',
#    'Mexico',
#    57590513,
#    "2015–16_ISU_World_Standings_and_Season's_World_Ranking"),
#   1862.0),
#  (('en.wikipedia', 'Argentina', 48980006, '2016_in_aviation'), 1859.0),
#  (('zh.wikipedia', 'Taiwan', 23730, '海地'), 1855.0),
#  (('en.wikipedia', 'India', 68273579, 'Bheemla_Nayak'), 1849.0),
#  (('en.wikipedia', 'Argentina', 52925867, '2018_in_American_television'),
#   1848.0),
#  (('zh.wikipedia', 'Hong Kong', 3597889, 'Wikipedia:首页'), 1841.0),
#  (('ja.wikipedia', 'Japan', 456928, 'ノースアジア大学明桜高等学校'), 1821.0),
#  (('en.wikipedia',
#    'Argentina',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   1820.0),
#  (('ml.wikipedia', 'India', 42375, 'ഒന്നാം_ഇന്ത്യൻ_സ്വാതന്ത്ര്യ_സമരം_(1857)'),
#   1818.0),
#  (('en.wikipedia', 'United Kingdom', 57379245, 'Incel'), 1816.0),
#  (('en.wikipedia', 'Argentina', 4848272, 'Donald_Trump'), 1815.0),
#  (('ko.wikipedia', 'South Korea', 1579615, '더블랙레이블'), 1795.0),
#  (('en.wikipedia',
#    'Mexico',
#    15910,
#    'List_of_compositions_by_Johann_Sebastian_Bach'),
#   1793.0),
#  (('ja.wikipedia', 'Japan', 1613, '日本のいちばん長い日'), 1783.0),
#  (('zh.wikipedia', 'Hong Kong', 594262, '破壞之王'), 1757.0),
#  (('en.wikipedia', 'India', 1425939, 'Indian_Idol'), 1747.0),
#  (('en.wikipedia', 'United States', 20646122, 'Index.html'), 1738.0),
#  (('ja.wikipedia', 'Japan', 5451, 'もののけ姫'), 1705.0),
#  (('it.wikipedia', 'Italy', 3363477, "Daniela_D'Angelo"), 1703.0),
#  (('ru.wikipedia', 'Russia', 80217, 'Новикова,_Клара_Борисовна'), 1700.0),
#  (('de.wikipedia', 'Germany', 154, 'Afghanistan'), 1675.0),
#  (('en.wikipedia', 'India', 14533, 'India'), 1674.0),
#  (('it.wikipedia', 'Italy', 65507, 'Talebani'), 1674.0),
#  (('en.wikipedia', 'Malaysia', 15580374, 'Main_Page'), 1655.0),
#  (('en.wikipedia', 'Sweden', 15580374, 'Main_Page'), 1649.0),
#  (('ko.wikipedia', 'South Korea', 27949, '광복절'), 1616.0),
#  (('ja.wikipedia', 'Japan', 3245938, '柴田阿弥'), 1610.0),
#  (('fi.wikipedia', 'Finland', 291, 'Wikipedia:Etusivu'), 1602.0),
#  (('en.wikipedia', 'United States', 60203476, 'Free_Guy'), 1596.0),
#  (('ja.wikipedia', 'Japan', 62134, 'A級戦犯'), 1590.0),
#  (('ja.wikipedia', 'Japan', 780840, '松井秀喜5打席連続敬遠'), 1576.0),
#  (('ja.wikipedia', 'Japan', 989912, '海原やすよ_ともこ'), 1573.0),
#  (('en.wikipedia', 'India', 2488796, 'Republic_Day_(India)'), 1565.0),
#  (('commons.wikimedia', 'United States', 1, 'Main_Page'), 1535.0),
#  (('ja.wikipedia', 'Japan', 43815, '梅田えりか'), 1493.0),
#  (('en.wikipedia', 'India', 803754, 'Kargil_War'), 1488.0)]
